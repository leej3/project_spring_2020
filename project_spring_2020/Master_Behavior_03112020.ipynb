# %%
#still in draft form as of 3.11.2020

import csv
import numpy as np
import pandas as pd

#import all behavior files
rootdir='/data/MoodGroup/07M0021_meg_analysis/MID_data/processed_MID_all/behavior_all/'
subjectlist=open('/data/MoodGroup/07M0021_meg_analysis/MID_data/scripts/processinglist.txt', 'r')
processinglist=subjectlist.readlines()
processinglist=list(map(lambda x: x.strip(), processinglist))
print(processinglist)
# Out:
# ['9', '10', '201', '202', '203', '204', '205', '206', '207', '208', '209', '210', '211', '212', '213', '1023', '1024', '1025', '1026', '1027', '1028', '1029', '1032', '1033', '1035', '1037', '1038', '1039', '1041', '1043', '1045', '1047', '1048', '1050', '1051', '1055', '1056', '1058', '1059', '1061', '1065']

# %%
all_beh_final=[]
for subject in processinglist:
    filename=rootdir + 'behavior_' + subject + '_MID_meanRT_acc.csv'
    df=pd.read_csv(filename,delimiter=',',header=None,skiprows=1)
    df[3]=subject
    #newcols=[3,0,1,2]
    #df=df.reindex(columns=newcols)
    print(df)
    #all_beh_final=all_beh_final.append(df,ignore_index=True)
    #print(all_beh_final)
#frame=pd.concat(all_beh_final)
# Out:
#       0           1         2  3
# 0   Win  271.307692  0.769231  9
# 1  Lose  265.461538  0.807692  9
# 2  Cont  283.807692  0.615385  9
#       0           1         2   3
# 0   Win  177.615385  0.615385  10
# 1  Lose  187.384615  0.615385  10
# 2  Cont  216.461538  0.653846  10
#       0           1         2    3
# 0   Win  268.000000  0.653846  201
# 1  Lose  252.000000  0.692308  201
# 2  Cont  251.807692  0.692308  201
#       0           1         2    3
# 0   Win  271.791667  0.692308  202
# 1  Lose  258.000000  0.807692  202
# 2  Cont  270.400000  0.576923  202
#       0           1         2    3
# 0   Win  335.190476  0.615385  203
# 1  Lose  323.500000  0.615385  203
# 2  Cont  349.818182  0.615385  203
#       0           1         2    3
# 0   Win  206.400000  0.692308  204
# 1  Lose  209.115385  0.653846  204
# 2  Cont  199.800000  0.653846  204
#       0           1         2    3
# 0   Win  174.041667  0.576923  205
# 1  Lose  176.384615  0.615385  205
# ...
