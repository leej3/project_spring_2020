# %%
import csv
import numpy as np
import pandas as pd
#import statistics

stimtime_1051=pd.read_csv('/data/MoodGroup/07M0021_meg_analysis/MID_data/subjects/sub-1051/meg/cue_marks',delimiter=' ',names=["Onset","Time"])
stimtime_1051
# Out:
#     Onset        Time
# 0       0   10.101667
# 1       0   19.338333
# 2       0   28.541667
# 3       0   37.645000
# 4       0   46.831667
# 5       0   56.536667
# 6       0   65.740000
# 7       0   74.843333
# 8       0   85.330000
# 9       0   94.733333
# 10      0  104.238333
# 11      0  113.941667
# 12      0  123.128333
# 13      0  132.431667
# 14      0  141.636667
# 15      0  150.840000
# 16      0  160.243333
# 17      0  169.530000
# 18      0  178.633333
# 19      0  187.836667
# 20      0  197.141667
# 21      0  206.228333
# 22      0  215.531667
# 23      0  224.735000
# 24      0  233.838333
# 25      0  243.341667
# 26      0  252.830000
# 27      0  262.133333
# 28      0  271.436667
# 29      0  280.740000
# ..    ...         ...
# 48      0  456.643333
# 49      0  466.046667
# 50      0  475.333333
# 51      0  484.536667
# 52      0  493.640000
# 53      0  502.743333
# 54      0  512.148333
# 55      0  521.235000
# 56      0  530.638333
# ...

# %%
data_read=pd.read_csv('/data/MoodGroup/07M0021_meg_analysis/MID_data/subjects/sub-1051/behavior/MID1-1051-1_behavior.txt',delimiter='	',skiprows=1,encoding='utf-16',engine='python')
data_read
# Out:
#    ExperimentName  Subject  Session  \
# 0            MID1     1051        1
# 1            MID1     1051        1
# 2            MID1     1051        1
# 3            MID1     1051        1
# 4            MID1     1051        1
# 5            MID1     1051        1
# 6            MID1     1051        1
# 7            MID1     1051        1
# 8            MID1     1051        1
# 9            MID1     1051        1
# 10           MID1     1051        1
# 11           MID1     1051        1
# 12           MID1     1051        1
# 13           MID1     1051        1
# 14           MID1     1051        1
# 15           MID1     1051        1
# 16           MID1     1051        1
# 17           MID1     1051        1
# 18           MID1     1051        1
# 19           MID1     1051        1
# 20           MID1     1051        1
# 21           MID1     1051        1
# 22           MID1     1051        1
# 23           MID1     1051        1
# 24           MID1     1051        1
# ...

# %%
trial_1051=data_read[['Cue']]
trial_1051
# Out:
#         Cue
# 0   Control
# 1     Lose2
# 2   Control
# 3      Win2
# 4      Win2
# 5      Win2
# 6     Lose2
# 7     Lose2
# 8     Lose2
# 9     Lose2
# 10  Control
# 11    Lose2
# 12  Control
# 13  Control
# 14     Win2
# 15  Control
# 16     Win2
# 17    Lose2
# 18    Lose2
# 19  Control
# 20  Control
# 21  Control
# 22  Control
# 23  Control
# 24     Win2
# 25     Win2
# 26     Win2
# 27    Lose2
# 28  Control
# 29    Lose2
# ..      ...
# 48    Lose2
# 49  Control
# 50  Control
# 51  Control
# 52  Control
# 53     Win2
# 54     Win2
# 55  Control
# 56  Control
# 57  Control
# 58     Win2
# 59    Lose2
# 60  Control
# 61    Lose2
# 62    Lose2
# 63    Lose2
# 64     Win2
# 65  Control
# 66     Win2
# 67  Control
# 68     Win2
# 69     Win2
# 70    Lose2
# 71     Win2
# 72     Win2
# 73     Win2
# 74    Lose2
# 75    Lose2
# 76  Control
# 77    Lose2
#
# [78 rows x 1 columns]

# %%
frames=[trial_1051,stimtime_1051]
stimtimes_1051_full=pd.concat(frames,axis=1)
stimtimes_1051_full
# Out:
#         Cue  Onset        Time
# 0   Control      0   10.101667
# 1     Lose2      0   19.338333
# 2   Control      0   28.541667
# 3      Win2      0   37.645000
# 4      Win2      0   46.831667
# 5      Win2      0   56.536667
# 6     Lose2      0   65.740000
# 7     Lose2      0   74.843333
# 8     Lose2      0   85.330000
# 9     Lose2      0   94.733333
# 10  Control      0  104.238333
# 11    Lose2      0  113.941667
# 12  Control      0  123.128333
# 13  Control      0  132.431667
# 14     Win2      0  141.636667
# 15  Control      0  150.840000
# 16     Win2      0  160.243333
# 17    Lose2      0  169.530000
# 18    Lose2      0  178.633333
# 19  Control      0  187.836667
# 20  Control      0  197.141667
# 21  Control      0  206.228333
# 22  Control      0  215.531667
# 23  Control      0  224.735000
# 24     Win2      0  233.838333
# 25     Win2      0  243.341667
# 26     Win2      0  252.830000
# 27    Lose2      0  262.133333
# 28  Control      0  271.436667
# ...

# %%
stimtimes_1051_win=stimtimes_1051_full[stimtimes_1051_full.Cue=='Win2']
df_1051_win=stimtimes_1051_win[stimtimes_1051_win.columns[1:3]]
df_1051_win
# Out:
#     Onset        Time
# 3       0   37.645000
# 4       0   46.831667
# 5       0   56.536667
# 14      0  141.636667
# 16      0  160.243333
# 24      0  233.838333
# 25      0  243.341667
# 26      0  252.830000
# 30      0  289.943333
# 33      0  317.538333
# 37      0  353.935000
# 39      0  372.443333
# 40      0  381.930000
# 41      0  391.033333
# 43      0  409.341667
# 44      0  418.945000
# 53      0  502.743333
# 54      0  512.148333
# 58      0  549.746667
# 64      0  604.835000
# 66      0  623.741667
# 68      0  641.931667
# 69      0  651.435000
# 71      0  670.543333
# 72      0  679.746667
# 73      0  689.033333

# %%
stimtimes_1051_lose=stimtimes_1051_full[stimtimes_1051_full.Cue=='Lose2']
df_1051_lose=stimtimes_1051_lose[stimtimes_1051_lose.columns[1:3]]
df_1051_lose
# Out:
#     Onset        Time
# 1       0   19.338333
# 6       0   65.740000
# 7       0   74.843333
# 8       0   85.330000
# 9       0   94.733333
# 11      0  113.941667
# 17      0  169.530000
# 18      0  178.633333
# 27      0  262.133333
# 29      0  280.740000
# 31      0  299.031667
# 32      0  308.335000
# 34      0  326.641667
# 35      0  335.745000
# 38      0  363.240000
# 46      0  437.735000
# 47      0  447.540000
# 48      0  456.643333
# 59      0  558.933333
# 61      0  577.140000
# 62      0  586.543333
# 63      0  595.746667
# 70      0  661.040000
# 74      0  698.136667
# 75      0  707.241667
# 77      0  726.248333

# %%
stimtimes_1051_cont=stimtimes_1051_full[stimtimes_1051_full.Cue=='Control']
df_1051_cont=stimtimes_1051_cont[stimtimes_1051_cont.columns[1:3]]
df_1051_cont
# Out:
#     Onset        Time
# 0       0   10.101667
# 2       0   28.541667
# 10      0  104.238333
# 12      0  123.128333
# 13      0  132.431667
# 15      0  150.840000
# 19      0  187.836667
# 20      0  197.141667
# 21      0  206.228333
# 22      0  215.531667
# 23      0  224.735000
# 28      0  271.436667
# 36      0  344.831667
# 42      0  400.136667
# 45      0  428.331667
# 49      0  466.046667
# 50      0  475.333333
# 51      0  484.536667
# 52      0  493.640000
# 55      0  521.235000
# 56      0  530.638333
# 57      0  539.841667
# 60      0  568.036667
# 65      0  614.538333
# 67      0  632.845000
# 76      0  716.545000

# %%
df_1051_win.to_csv('/data/MoodGroup/07M0021_meg_analysis/MID_data/subjects/sub-1051/meg/1051_win.txt',index=False,header=False,sep=' ')
df_1051_lose.to_csv('/data/MoodGroup/07M0021_meg_analysis/MID_data/subjects/sub-1051/meg/1051_lose.txt',index=False,header=False,sep=' ')
df_1051_cont.to_csv('/data/MoodGroup/07M0021_meg_analysis/MID_data/subjects/sub-1051/meg/1051_cont.txt',index=False,header=False,sep=' ')

# %%
#behavior!
data_read=pd.read_csv('/data/MoodGroup/07M0021_meg_analysis/MID_data/subjects/sub-1051/behavior/MID1-1051-1_behavior.txt',delimiter='	',skiprows=1,encoding='utf-16',engine='python')

# %%
behavior_1051=data_read[['Cue','ResponseType','TrialCategory','Target.RT']]
behavior_1051
# Out:
#         Cue  ResponseType TrialCategory  Target.RT
# 0   Control    NoResponse       Neutral        512
# 1     Lose2  GoodResponse   AvoidedLoss        321
# 2   Control  GoodResponse       Neutral        227
# 3      Win2  GoodResponse           Win        284
# 4      Win2  GoodResponse           Win        254
# 5      Win2  GoodResponse           Win        250
# 6     Lose2  GoodResponse   AvoidedLoss        249
# 7     Lose2  GoodResponse   AvoidedLoss        256
# 8     Lose2  GoodResponse   AvoidedLoss        216
# 9     Lose2  GoodResponse   AvoidedLoss        236
# 10  Control  GoodResponse       Neutral        249
# 11    Lose2  GoodResponse   AvoidedLoss        252
# 12  Control  GoodResponse       Neutral        217
# 13  Control  GoodResponse       Neutral        248
# 14     Win2  GoodResponse           Win        230
# 15  Control  GoodResponse       Neutral        198
# 16     Win2  GoodResponse           Win        202
# ...

# %%
behavior_1051_win=behavior_1051[behavior_1051.Cue=='Win2']
behavior_1051_win_hit=behavior_1051_win[behavior_1051_win.ResponseType=='GoodResponse']
behavior_1051_win_hit
# Out:
#      Cue  ResponseType TrialCategory  Target.RT
# 3   Win2  GoodResponse           Win        284
# 4   Win2  GoodResponse           Win        254
# 5   Win2  GoodResponse           Win        250
# 14  Win2  GoodResponse           Win        230
# 16  Win2  GoodResponse           Win        202
# 40  Win2  GoodResponse           Win        194
# 41  Win2  GoodResponse           Win        199
# 43  Win2  GoodResponse           Win        192
# 44  Win2  GoodResponse           Win        190
# 53  Win2  GoodResponse           Win        228
# 54  Win2  GoodResponse           Win        227
# 58  Win2  GoodResponse           Win        245
# 64  Win2  GoodResponse           Win        218
# 66  Win2  GoodResponse           Win        223
# 68  Win2  GoodResponse           Win        213
# 69  Win2  GoodResponse           Win        227
# 71  Win2  GoodResponse           Win        208
# 72  Win2  GoodResponse           Win        190
# 73  Win2  GoodResponse           Win        201

# %%
behavior_1051_win_miss=behavior_1051_win[behavior_1051_win.ResponseType=='NoResponse']
behavior_1051_win_miss
# Out:
#      Cue ResponseType TrialCategory  Target.RT
# 24  Win2   NoResponse     MissedWin        219
# 25  Win2   NoResponse     MissedWin        249
# 26  Win2   NoResponse     MissedWin        208
# 30  Win2   NoResponse     MissedWin        227
# 33  Win2   NoResponse     MissedWin        212
# 37  Win2   NoResponse     MissedWin        219
# 39  Win2   NoResponse     MissedWin        262

# %%
behavior_1051_lose=behavior_1051[behavior_1051.Cue=='Lose2']
behavior_1051_lose_hit=behavior_1051_lose[behavior_1051_lose.ResponseType=='GoodResponse']
behavior_1051_lose_hit
# Out:
#       Cue  ResponseType TrialCategory  Target.RT
# 1   Lose2  GoodResponse   AvoidedLoss        321
# 6   Lose2  GoodResponse   AvoidedLoss        249
# 7   Lose2  GoodResponse   AvoidedLoss        256
# 8   Lose2  GoodResponse   AvoidedLoss        216
# 9   Lose2  GoodResponse   AvoidedLoss        236
# 11  Lose2  GoodResponse   AvoidedLoss        252
# 17  Lose2  GoodResponse   AvoidedLoss        179
# 18  Lose2  GoodResponse   AvoidedLoss        180
# 46  Lose2  GoodResponse   AvoidedLoss        202
# 47  Lose2  GoodResponse   AvoidedLoss        192
# 48  Lose2  GoodResponse   AvoidedLoss        197
# 59  Lose2  GoodResponse   AvoidedLoss        246
# 61  Lose2  GoodResponse   AvoidedLoss        222
# 62  Lose2  GoodResponse   AvoidedLoss        219
# 63  Lose2  GoodResponse   AvoidedLoss        189
# 70  Lose2  GoodResponse   AvoidedLoss        202
# 75  Lose2  GoodResponse   AvoidedLoss        184

# %%
behavior_1051_lose_miss=behavior_1051_lose[behavior_1051_lose.ResponseType=='NoResponse']
behavior_1051_lose_miss
# Out:
#       Cue ResponseType TrialCategory  Target.RT
# 27  Lose2   NoResponse          Loss        561
# 29  Lose2   NoResponse          Loss        268
# 31  Lose2   NoResponse          Loss        238
# 32  Lose2   NoResponse          Loss        210
# 35  Lose2   NoResponse          Loss        207
# 74  Lose2   NoResponse          Loss        217
# 77  Lose2   NoResponse          Loss          0

# %%
behavior_1051_cont=behavior_1051[behavior_1051.Cue=='Control']
behavior_1051_cont_hit=behavior_1051_cont[behavior_1051_cont.ResponseType=='GoodResponse']
behavior_1051_cont_hit
# Out:
#         Cue  ResponseType TrialCategory  Target.RT
# 2   Control  GoodResponse       Neutral        227
# 10  Control  GoodResponse       Neutral        249
# 12  Control  GoodResponse       Neutral        217
# 13  Control  GoodResponse       Neutral        248
# 15  Control  GoodResponse       Neutral        198
# 19  Control  GoodResponse       Neutral        227
# 20  Control  GoodResponse       Neutral        200
# 22  Control  GoodResponse       Neutral        216
# 42  Control  GoodResponse       Neutral        213
# 45  Control  GoodResponse       Neutral        184
# 49  Control  GoodResponse       Neutral        208
# 50  Control  GoodResponse       Neutral        188
# 51  Control  GoodResponse       Neutral        193
# 52  Control  GoodResponse       Neutral        206
# 55  Control  GoodResponse       Neutral        223
# 56  Control  GoodResponse       Neutral        196
# 57  Control  GoodResponse       Neutral        228
# ...

# %%
behavior_1051_cont_miss=behavior_1051_cont[behavior_1051_cont.ResponseType=='NoResponse']
behavior_1051_cont_miss
# Out:
#         Cue ResponseType TrialCategory  Target.RT
# 0   Control   NoResponse       Neutral        512
# 21  Control   NoResponse       Neutral          0
# 23  Control   NoResponse       Neutral        235
# 28  Control   NoResponse       Neutral        241
# 36  Control   NoResponse       Neutral        218
# 76  Control   NoResponse       Neutral        202

# %%
win_hit_RT_1051=behavior_1051_win_hit['Target.RT'][behavior_1051_win_hit['Target.RT']!=0].mean()
win_hit_acc_1051=behavior_1051_win_hit.count()
win_miss_RT_1051=behavior_1051_win_miss['Target.RT'][behavior_1051_win_miss['Target.RT']!=0].mean()
win_miss_acc_1051=behavior_1051_win_miss.count()
lose_hit_RT_1051=behavior_1051_lose_hit['Target.RT'][behavior_1051_lose_hit['Target.RT']!=0].mean()
lose_hit_acc_1051=behavior_1051_lose_hit.count()
lose_miss_RT_1051=behavior_1051_lose_miss['Target.RT'][behavior_1051_lose_miss['Target.RT']!=0].mean()
lose_miss_acc_1051=behavior_1051_lose_miss.count()
cont_hit_RT_1051=behavior_1051_cont_hit['Target.RT'][behavior_1051_cont_hit['Target.RT']!=0].mean()
cont_hit_acc_1051=behavior_1051_cont_hit.count()
cont_miss_RT_1051=behavior_1051_cont_miss['Target.RT'][behavior_1051_cont_miss['Target.RT']!=0].mean()
cont_miss_acc_1051=behavior_1051_cont_miss.count()

# %%
d_1051={'Type':['Win','Win','Lose','Lose','Cont','Cont'],
   'Outcome':['Hit','Miss','Hit','Miss','Hit','Miss'],
   'RT':[win_hit_RT_1051,win_miss_RT_1051,lose_hit_RT_1051,lose_miss_RT_1051,cont_hit_RT_1051,cont_miss_RT_1051],
   'Acc':[win_hit_acc_1051.Cue,win_miss_acc_1051.Cue,lose_hit_acc_1051.Cue,lose_miss_acc_1051.Cue,cont_hit_acc_1051.Cue,cont_miss_acc_1051.Cue]}
df_1051=pd.DataFrame(d_1051)
df_1051=df_1051[['Type','Outcome','RT','Acc']]
df_1051
# Out:
#    Type Outcome          RT  Acc
# 0   Win     Hit  219.736842   19
# 1   Win    Miss  228.000000    7
# 2  Lose     Hit  220.117647   17
# 3  Lose    Miss  283.500000    7
# 4  Cont     Hit  213.250000   20
# 5  Cont    Miss  281.600000    6

# %%
df_1051.to_csv('/data/MoodGroup/07M0021_meg_analysis/MID_data/subjects/sub-1051/behavior/behavior_1051_MID.csv',index=False)

# %%
win_RT_1051=behavior_1051_win['Target.RT'][behavior_1051_win['Target.RT']!=0].mean()
lose_RT_1051=behavior_1051_lose['Target.RT'][behavior_1051_lose['Target.RT']!=0].mean()
cont_RT_1051=behavior_1051_cont['Target.RT'][behavior_1051_cont['Target.RT']!=0].mean()

# %%
win_acc_1051=win_hit_acc_1051.Cue/26.0
lose_acc_1051=lose_hit_acc_1051.Cue/26.0
cont_acc_1051=cont_hit_acc_1051.Cue/26.0

# %%
d_1051_2={'Type':['Win','Lose','Cont'],'RT':[win_RT_1051,lose_RT_1051,cont_RT_1051],'Acc':[win_acc_1051,lose_acc_1051,cont_acc_1051]}
df_1051_2=pd.DataFrame(d_1051_2)
df_1051_2=df_1051_2[['Type','RT','Acc']]
df_1051_2
# Out:
#    Type          RT       Acc
# 0   Win  221.961538  0.730769
# 1  Lose  230.120000  0.653846
# 2  Cont  226.920000  0.769231

# %%
df_1051_2.to_csv('/data/MoodGroup/07M0021_meg_analysis/MID_data/subjects/sub-1051/behavior/behavior_1051_MID_meanRT_acc.csv',index=False)

# %%
df_1051_2.to_csv('/data/MoodGroup/07M0021_meg_analysis/MID_data/processed_MID_all/behavior_all/behavior_1051_MID_meanRT_acc.csv',index=False)
